# %% [markdown]
# # Explore data
#
# Placeholder notebook for poking at loaded subgraphs and traversal traces.
#
# ```python
# from kgat.data.loaders import load_records
# from kgat.graph.inmemory import InMemoryKGStore
#
# records = load_records('../data/sample', split='dev', dataset='sample')
# store = InMemoryKGStore.from_records(records)
# store.load_question_subgraph(records[0].qid)
# print(records[0].question.text)
# print(store.relations_of(records[0].question.topic_entities[0]))
# ```
